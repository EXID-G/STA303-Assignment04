# %%
#内嵌画图，省略掉plt.show()这一步，直接显示图像。
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objs as go

# plt.rcParams['font.sans-serif'] = ['SimHei']  #防止中文乱码，还可以有Microsoft YaHei
# plt.rcParams["axes.unicode_minus"] = False   #字符显示，防止负号乱码

import warnings
warnings.filterwarnings('ignore')

# %%
plt.style.use("ggplot")

# %%
resnet18_fashionminist_data = pd.read_csv('./csvdata/resnet18-fashionminist.CSV')
resnet18_fashionminist_data
# Out:
#              predictor    score_function  coverage_rate  average_size
# 0       SplitPredictor               THR       0.892500      1.058250
# 1     ClusterPredictor               THR       0.892500      1.058500
# 2   ClassWisePredictor               THR       0.900625      1.182000
# 3       SplitPredictor               APS       0.897125      1.219500
# 4     ClusterPredictor               APS       0.893500      1.213375
# 5   ClassWisePredictor               APS       0.901750      1.349000
# 6       SplitPredictor  SAPS(weight=0.2)       0.892875      1.187375
# 7     ClusterPredictor  SAPS(weight=0.2)       0.891625      1.184625
# 8   ClassWisePredictor  SAPS(weight=0.2)       0.892125      1.384250
# 9       SplitPredictor         RAPS(1,0)       0.895500      1.073000
# 10    ClusterPredictor         RAPS(1,0)       0.895500      1.074500
# 11  ClassWisePredictor         RAPS(1,0)       0.893375      1.329625

# %%
plt.figure(figsize=(10, 6))
sns.set_context(font_scale=1.0)
sns.scatterplot(x = "coverage_rate", y = "average_size",hue="predictor",style="score_function",s = 250, data = resnet18_fashionminist_data);
plt.title("Scatter plot of resnet18_fashionminist",fontsize = 18)

plt.savefig("./csvdata/figure/Scatter plot of resnet18_fashionminist.svg")
